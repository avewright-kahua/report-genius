# %%
import pyodbc
import pandas as pd
import json
import socket
from pathlib import Path

# Database connection parameters
server = "demo01"
database = "demo01_KahuaDataStore_11610510910911783"
username = "demo01_kahuaDataStoreUser_89122113112107117"
password = "Playful3"

# First, test basic network connectivity
print("🔍 Diagnosing connection...")
try:
    ip = socket.gethostbyname(server)
    print(f"✅ DNS resolved: {server} -> {ip}")
except socket.gaierror:
    print(f"❌ DNS lookup failed for {server}")

# Test if port 1433 is reachable
try:
    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    sock.settimeout(5)
    result = sock.connect_ex((server, 1433))
    sock.close()
    if result == 0:
        print(f"✅ Port 1433 is open on {server}")
    else:
        print(f"❌ Port 1433 is NOT reachable on {server}")
except Exception as e:
    print(f"❌ Port check failed: {e}")

# Try to connect to the database (using connection params instead of string to handle special chars)
conn = None
try:
    print("\n🔌 Attempting database connection...")
    # Use braces around password to handle special characters like @
    connection_string = (
        f"DRIVER={{ODBC Driver 17 for SQL Server}};"
        f"SERVER={server};"
        f"DATABASE={database};"
        f"UID={username};"
        f"PWD={{{password}}};"  # Extra braces to escape special chars
        f"Connection Timeout=10"
    )
    conn = pyodbc.connect(connection_string)
    print("✅ Successfully connected to the database!")
    
    # Get list of tables
    query = "SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES WHERE TABLE_TYPE = 'BASE TABLE'"
    tables = pd.read_sql(query, conn)
    print(f"\n📊 Available tables in the DataStore ({len(tables)} tables):")
    print(tables)
except pyodbc.Error as e:
    print(f"❌ Database connection failed: {e}")
# Out:
# 🔍 Diagnosing connection...
# ✅ DNS resolved: demo01 -> 10.10.12.181
# ✅ Port 1433 is open on demo01
#
# 🔌 Attempting database connection...
# ✅ Successfully connected to the database!
# C:\Users\AWright\AppData\Local\Temp\ipykernel_34784\2411194386.py:52: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tables = pd.read_sql(query, conn)
# 📊 Available tables in the DataStore (1889 tables):
#                                              TABLE_NAME
# 0     centrenium_CloseoutPackage_CloseoutPackageRevi...
# 1                  kahua_SecureSignature_EnvelopeStatus
# 2     runding_PerformanceTask_PerformanceTask_Perfor...
# 3     kahua_AssetManager_Assets_PhotovalicSystemAsse...
# 4     kahua_Sustainability_ScopeType_HVAC_BoilersorH...
# ...                                                 ...
# 1884                ezApps_Checklist_Checklist_Sections
# 1885              kahua_AEC_BidSolicitations_BidCompany
# 1886       runding_kahua_scheduleTask_Task_Predecessors
# 1887                 kahua_Core_kahua_FileData_Comments
# 1888  kahua_AssetManager_Types_GlassType_DataScope_P...
#
# [1889 rows x 1 columns]

# %%
# Search for tables by keyword
def search_tables(keyword):
    """Find tables containing a keyword"""
    matches = tables[tables['TABLE_NAME'].str.contains(keyword, case=False)]
    print(f"Found {len(matches)} tables matching '{keyword}':")
    return matches

# Common entity types to explore
print("🔍 Quick table searches:")
print(f"\nContracts: {len(search_tables('Contract').head(0))} tables")
print(f"RFIs: {len(search_tables('RFI').head(0))} tables")
print(f"Submittals: {len(search_tables('Submittal').head(0))} tables")
print(f"Punch Lists: {len(search_tables('Punch').head(0))} tables")
print(f"Change Orders: {len(search_tables('ChangeOrder').head(0))} tables")
# Out:
# 🔍 Quick table searches:
# Found 79 tables matching 'Contract':
#
# Contracts: 0 tables
# Found 19 tables matching 'RFI':
# RFIs: 0 tables
# Found 45 tables matching 'Submittal':
# Submittals: 0 tables
# Found 14 tables matching 'Punch':
# Punch Lists: 0 tables
# Found 35 tables matching 'ChangeOrder':
# Change Orders: 0 tables

# %%
# View Contract tables
contract_tables = search_tables('Contract')
contract_tables.head(20)
# Out:
# Found 79 tables matching 'Contract':
#                                             TABLE_NAME
# 7    kahua_ClientContractChangeOrder_ClientContract...
# 36                 kahua_ClientContract_ClientContract
# 57   kahua_ClientContractChangeOrder_ClientContract...
# 75        kahua_ClientContract_ClientContract_Comments
# 122          kahua_ClientContract_ClientContract_Items
# 398  kahua_ClientContractInvoice_ClientContractInvoice
# 443  kahua_ClientContractInvoice_ClientContractInvo...
# 479  kahua_ContractChangeOrder_ContractChangeOrderItem
# 490  kahua_ClientContractInvoice_ClientContractInvo...
# 522  kahua_ContractChangeOrder_ContractChangeOrderI...
# 534  kahua_ClientContractInvoice_ClientContractInvo...
# 566  kahua_ContractChangeOrder_ContractChangeOrderI...
# 578  kahua_ClientContractInvoice_ClientContractInvo...
# 614      kahua_ContractChangeOrder_ContractChangeOrder
# 625  kahua_ClientContractInvoice_ClientContractInvo...
# 658  kahua_ContractChangeOrder_ContractChangeOrder_...
# 703  kahua_ContractChangeOrder_ContractChangeOrder_...
# 744  kahua_ContractChangeOrder_ContractChangeOrder_...
# 752  kahua_ClientContractInvoice_ClientContractInvo...
# 790  kahua_ContractChangeOrder_ContractChangeOrder_...

# %%
# Helper to preview a table's structure and sample data
def preview_table(table_name, limit=5):
    """Preview a table's columns and sample rows"""
    print(f"\n📋 Table: {table_name}")
    print("="*60)
    
    # Get column info
    col_query = f"""
    SELECT COLUMN_NAME, DATA_TYPE, IS_NULLABLE 
    FROM INFORMATION_SCHEMA.COLUMNS 
    WHERE TABLE_NAME = '{table_name}'
    ORDER BY ORDINAL_POSITION
    """
    columns = pd.read_sql(col_query, conn)
    print(f"\n📐 Columns ({len(columns)}):")
    print(columns.to_string())
    
    # Get sample data
    try:
        sample_query = f"SELECT TOP {limit} * FROM [{table_name}]"
        sample = pd.read_sql(sample_query, conn)
        print(f"\n📊 Sample data ({len(sample)} rows):")
        return sample
    except Exception as e:
        print(f"⚠️ Could not fetch sample: {e}")
        return columns

# %%
# Preview the main Contract table
preview_table('kahua_Contract_Contract')
# Out:
# 📋 Table: kahua_Contract_Contract
# ============================================================
#
# 📐 Columns (95):
#                             COLUMN_NAME DATA_TYPE IS_NULLABLE
# 0                                    Id    bigint          NO
# 1                     DomainPartitionId    bigint         YES
# 2                           PartitionId    bigint         YES
# 3                       CreatedDateTime  datetime         YES
# 4                      ModifiedDateTime  datetime         YES
# 5                         EntityLinkUrl  nvarchar         YES
# 6                               Addenda  nvarchar         YES
# 7                 ApprovedChangesAmount   decimal         YES
# 8                            AssignedTo  nvarchar         YES
# 9                             AwardDate  datetime         YES
# 10                     ClientCompany_Id    bigint         YES
# 11             ClientCompanyLocation_Id    bigint         YES
# 12               ClientCompanyOffice_Id    bigint         YES
# 13                     ClientContact_Id    bigint         YES
# 14           ContractApprovedTotalValue   decimal         YES
# 15             ContractGrossTotalAmount   decimal         YES
# 16             ContractItemsTotalAmount   decimal         YES
# 17                 ContractorCompany_Id    bigint         YES
# 18         ContractorCompanyLocation_Id    bigint         YES
# 19           ContractorCompanyOffice_Id    bigint         YES
# 20                 ContractorContact_Id    bigint         YES
# 21            ContractPendingTotalValue   decimal         YES
# 22          ContractProjectedTotalValue   decimal         YES
# 23             ContractSignerContact_Id    bigint         YES
# 24             CostItemsTotalTotalValue   decimal         YES
# 25                CurrentContractAmount   decimal         YES
# 26                    CustomContact1_Id    bigint         YES
# 27                    CustomContact2_Id    bigint         YES
# 28                    CustomContact3_Id    bigint         YES
# 29                    CustomContact4_Id    bigint         YES
# 30                    CustomContact5_Id    bigint         YES
# 31                          CustomDate1  datetime         YES
# 32                          CustomDate2  datetime         YES
# 33                          CustomDate3  datetime         YES
# 34                          CustomDate4  datetime         YES
# 35                          CustomDate5  datetime         YES
# 36                        CustomLookup1  nvarchar         YES
# 37                        CustomLookup2  nvarchar         YES
# 38                        CustomLookup3  nvarchar         YES
# 39                        CustomLookup4  nvarchar         YES
# 40                        CustomLookup5  nvarchar         YES
# 41                          CustomText1  nvarchar         YES
# 42                          CustomText2  nvarchar         YES
# 43                          CustomText3  nvarchar         YES
# 44                          CustomText4  nvarchar         YES
# 45                          CustomText5  nvarchar         YES
# 46                 CustomUnlimitedText1  nvarchar         YES
# 47                 CustomUnlimitedText2  nvarchar         YES
# 48                 CustomUnlimitedText3  nvarchar         YES
# 49                 CustomUnlimitedText4  nvarchar         YES
# 50                 CustomUnlimitedText5  nvarchar         YES
# 51                                 Date  datetime         YES
# 52                 DateContractRequired  datetime         YES
# 53                         DateExecuted  datetime         YES
# 54                         DateReviewed  datetime         YES
# 55                    DateSentForReview  datetime         YES
# 56                 DateSentForSignature  datetime         YES
# 57                          Description  nvarchar         YES
# 58                ExecutedChangesAmount   decimal         YES
# 59        ExecutedChangesContractAmount   decimal         YES
# 60                      FinalCompletion  datetime         YES
# 61                    GeneralProvisions  nvarchar         YES
# 62                 ItemsIncludeQuantity       bit         YES
# 63                    LiquidatedDamages       bit         YES
# 64           LiquidatedDamagesStartDate  datetime         YES
# 65              LiquidatedDamagesPerDay   decimal         YES
# 66   LiquidatedDamagesNotToExceedAmount   decimal         YES
# 67                                Notes  nvarchar         YES
# 68                        NoticeOfAward  datetime         YES
# 69                   NoticeOfCompletion  datetime         YES
# 70                    NotToExceedAmount   decimal         YES
# 71                               Number  nvarchar         YES
# 72                        NumberOfPages    bigint         YES
# 73               OriginalContractAmount   decimal         YES
# 74                            Parent_Id    bigint         YES
# 75                          ScheduleEnd  datetime         YES
# 76                        ScheduleStart  datetime         YES
# 77                          ScopeOfWork  nvarchar         YES
# 78                            Status_Id    bigint         YES
# 79          StoredMaterialRetainageRate   decimal         YES
# 80          SubstantialCompletionActual  datetime         YES
# 81                                 Type  nvarchar         YES
# 82                       WorkflowStatus  nvarchar         YES
# 83                       WorkPackage_Id    bigint         YES
# 84                    WorkRetainageRate   decimal         YES
# 85                         CurrencyCode  nvarchar         YES
# 86                       CurrencyRateId    bigint         YES
# 87                   CurrencyRateTypeId    bigint         YES
# 88                 CurrencyRateToDomain   decimal         YES
# 89               CurrencyRateToDocument   decimal         YES
# 90     CurrencyRateLastModifiedDateTime  datetime         YES
# 91  LinkChangeOrderItemsToContractItems       bit         YES
# 92                         CreatedBy_Id    bigint         YES
# 93                    CostUnitEntryType  nvarchar         YES
# 94                    OverbillingLimits  nvarchar         YES
#
# 📊 Sample data (5 rows):
# C:\Users\AWright\AppData\Local\Temp\ipykernel_34784\3188530906.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   columns = pd.read_sql(col_query, conn)
# C:\Users\AWright\AppData\Local\Temp\ipykernel_34784\3188530906.py:21: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sample = pd.read_sql(sample_query, conn)
#         Id  DomainPartitionId  PartitionId         CreatedDateTime  \
# 0  5024152            5023805      5023805 2020-06-03 15:47:37.017
# 1  5024158            5023805      5023805 2020-06-03 15:50:54.990
# 2  5024245            5023805      5023805 2020-06-03 16:30:52.767
# 3  5028065            5024551      5024551 2020-06-03 21:35:50.250
# 4  5212019            5024551      5024551 2020-07-07 17:10:49.073
#
#          ModifiedDateTime                                    EntityLinkUrl  \
# 0 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z4CA998
# 1 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z4CA99E
# 2 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z4CA9F5
# 3 2023-06-19 14:03:27.187  https://demo01launch.kahua.com/link/SCD0z4CB8E1
# 4 2023-02-01 15:14:42.773  https://demo01launch.kahua.com/link/SCD0z4F8773
#
#   Addenda  ApprovedChangesAmount AssignedTo  AwardDate  ...  CurrencyCode  \
# 0    None                 3500.0       None        NaT  ...           USD
# 1    None                    0.0       None        NaT  ...           USD
# 2    None                    0.0       None        NaT  ...           USD
# 3    None               127845.0       None 2020-04-01  ...           USD
# 4    None                 9000.0       None        NaT  ...           USD
#
#   CurrencyRateId  CurrencyRateTypeId  CurrencyRateToDomain  \
# 0            714                 617                   1.0
# 1            714                 617                   1.0
# 2            714                 617                   1.0
# 3            714                 617                   1.0
# 4            714                 617                   1.0
#
#    CurrencyRateToDocument  CurrencyRateLastModifiedDateTime  \
# 0                     1.0           2020-06-03 15:47:37.000
# 1                     1.0           2020-06-03 15:50:54.960
# 2                     1.0           2020-06-03 16:30:52.753
# 3                     1.0           2020-06-03 21:35:50.220
# 4                     1.0           2020-07-07 17:10:49.040
#
#    LinkChangeOrderItemsToContractItems  CreatedBy_Id CostUnitEntryType  \
# 0                                 None       5005854        TotalValue
# 1                                 None       5005854        TotalValue
# 2                                 None       5005854        TotalValue
# 3                                 None       5005854        TotalValue
# 4                                 None       5005854        TotalValue
#
#    OverbillingLimits
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None
#
# [5 rows x 95 columns]

# %%
# Run a custom query
def run_query(sql, limit=100):
    """Execute a SQL query and return results as DataFrame"""
    df = pd.read_sql(sql, conn)
    print(f"Returned {len(df)} rows, {len(df.columns)} columns")
    return df

# Example: Get all contracts with key fields
contracts_df = run_query("""
    SELECT TOP 50 * FROM [kahua_Contract_Contract]
""")
contracts_df
# Out:
# Returned 50 rows, 95 columns
# C:\Users\AWright\AppData\Local\Temp\ipykernel_34784\2411187552.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)
#          Id  DomainPartitionId  PartitionId         CreatedDateTime  \
# 0   5024152            5023805      5023805 2020-06-03 15:47:37.017
# 1   5024158            5023805      5023805 2020-06-03 15:50:54.990
# 2   5024245            5023805      5023805 2020-06-03 16:30:52.767
# 3   5028065            5024551      5024551 2020-06-03 21:35:50.250
# 4   5212019            5024551      5024551 2020-07-07 17:10:49.073
# 5   5373562            5370105      5370105 2020-07-17 13:44:40.183
# 6   5373592            5370105      5370105 2020-07-17 13:46:55.327
# 7   5373635            5370105      5370105 2020-07-17 13:49:19.920
# 8   5376878            5370105      5370105 2020-07-20 13:29:37.593
# 9   5397624            5022361      5022361 2020-07-26 21:41:26.920
# 10  5397864            5022361      5022361 2020-07-26 22:04:18.203
# 11  5412384            5022361      5022361 2020-07-29 16:15:09.977
# 12  5412540            5022361      5022361 2020-07-29 16:52:01.660
# 13  5487728            5145848      5145848 2020-08-14 21:30:11.497
# 14  5487840            5145848      5145848 2020-08-14 21:33:25.170
# 15  5487868            5145848      5145848 2020-08-14 21:40:14.203
# 16  6211471            5022361      5022361 2021-01-03 21:18:46.343
# 17  6617610            5024564      5024564 2021-02-17 18:51:04.323
# 18  6617666            5024577      5024577 2021-02-17 18:52:02.877
# 19  6635326            6635144      6635144 2021-03-02 15:55:49.253
# 20  6635338            6635144      6635144 2021-03-02 15:56:36.267
# 21  6635861            6635144      6635144 2021-03-02 16:51:10.090
# 22  6798062            6797110      6797110 2021-03-08 18:41:37.430
# 23  6798358            6797110      6797110 2021-03-08 18:53:59.217
# 24  6803418            6801009      6801009 2021-03-09 21:53:11.573
# 25  6803424            6801009      6801009 2021-03-09 21:54:01.180
# 26  6803434            6801170      6801170 2021-03-09 21:56:08.537
# 27  6803446            6801170      6801170 2021-03-09 21:57:48.550
# 28  6803452            6801331      6801331 2021-03-09 21:58:48.850
# 29  6803461            6801331      6801331 2021-03-09 22:00:13.447
# 30  6803467            6801492      6801492 2021-03-09 22:01:13.610
# 31  6803473            6801492      6801492 2021-03-09 22:02:09.300
# 32  6803479            6801653      6801653 2021-03-09 22:03:31.647
# 33  6803485            6801653      6801653 2021-03-09 22:04:18.750
# 34  6803491            6801814      6801814 2021-03-09 22:05:36.790
# 35  6803497            6801814      6801814 2021-03-09 22:06:26.053
# 36  6806056            5022361      5022361 2021-03-10 14:28:23.293
# 37  6807376            5022361      5022361 2021-03-11 16:42:15.200
# 38  6959524            5022361      5022361 2021-03-23 14:21:57.583
# 39  6978058            5022361      5022361 2021-03-29 21:33:40.720
# 40  6983025            6982120      6982120 2021-03-31 15:14:57.667
# 41  6983063            6982120      6982120 2021-03-31 15:22:01.810
# 42  6986993            5024551      5024551 2021-04-01 18:58:43.183
# 43  7000167            6999207      6999207 2021-04-07 17:45:08.333
# 44  7000186            6999207      6999207 2021-04-07 17:48:44.330
# 45  7009140            5024551      5024551 2021-04-14 14:08:42.850
# 46  7024305            7023251      7023251 2021-04-22 16:45:01.837
# 47  7024325            7023251      7023251 2021-04-22 16:46:58.877
# 48  7025558            5024551      5024551 2021-04-27 19:54:22.017
# 49  7047476            7046647      7046647 2021-05-07 15:15:27.740
#
#           ModifiedDateTime                                    EntityLinkUrl  \
# 0  2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z4CA998
# 1  2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z4CA99E
# 2  2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z4CA9F5
# 3  2023-06-19 14:03:27.187  https://demo01launch.kahua.com/link/SCD0z4CB8E1
# 4  2023-02-01 15:14:42.773  https://demo01launch.kahua.com/link/SCD0z4F8773
# 5  2022-11-30 18:16:12.433  https://demo01launch.kahua.com/link/SCD0z51FE7A
# 6  2022-11-09 15:58:39.373  https://demo01launch.kahua.com/link/SCD0z51FE98
# 7  2023-02-07 21:16:23.390  https://demo01launch.kahua.com/link/SCD0z51FEC3
# 8  2022-11-30 18:16:09.780  https://demo01launch.kahua.com/link/SCD0z520B6E
# 9  2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z525C78
# 10 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z525D68
# 11 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z529620
# 12 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z5296BC
# 13 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z53BC70
# 14 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z53BCE0
# 15 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z53BCFC
# 16 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z5EC78F
# 17 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z64FA0A
# 18 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z64FA42
# 19 2022-12-06 19:46:51.927  https://demo01launch.kahua.com/link/SCD0z653F3E
# 20 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z653F4A
# 21 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z654155
# 22 2023-02-02 19:53:10.577  https://demo01launch.kahua.com/link/SCD0z67BAEE
# 23 2024-05-08 18:30:17.983  https://demo01launch.kahua.com/link/SCD0z67BC16
# 24 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z67CFDA
# 25 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z67CFE0
# 26 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z67CFEA
# 27 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z67CFF6
# 28 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z67CFFC
# 29 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z67D005
# 30 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z67D00B
# 31 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z67D011
# 32 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z67D017
# 33 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z67D01D
# 34 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z67D023
# 35 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z67D029
# 36 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z67DA28
# 37 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z67DF50
# 38 2022-08-04 19:00:25.147  https://demo01launch.kahua.com/link/SCD0z6A31A4
# 39 2022-08-04 19:00:22.770  https://demo01launch.kahua.com/link/SCD0z6A7A0A
# 40 2026-01-06 13:54:21.853  https://demo01launch.kahua.com/link/SCD0z6A8D71
# 41 2026-01-06 14:06:01.717  https://demo01launch.kahua.com/link/SCD0z6A8D97
# 42 2022-08-04 19:00:22.770  https://demo01launch.kahua.com/link/SCD0z6A9CF1
# 43 2023-02-07 17:54:15.180  https://demo01launch.kahua.com/link/SCD0z6AD067
# 44 2023-02-14 20:08:19.953  https://demo01launch.kahua.com/link/SCD0z6AD07A
# 45 2023-03-23 16:50:36.387  https://demo01launch.kahua.com/link/SCD0z6AF374
# 46 2024-02-01 17:29:14.513  https://demo01launch.kahua.com/link/SCD0z6B2EB1
# 47 2024-02-01 17:29:12.917  https://demo01launch.kahua.com/link/SCD0z6B2EC5
# 48 2023-03-23 16:50:34.947  https://demo01launch.kahua.com/link/SCD0z6B3396
# 49 2022-08-04 19:00:22.770  https://demo01launch.kahua.com/link/SCD0z6B8934
#
#               Addenda  ApprovedChangesAmount  \
# 0                None                 3500.0
# 1                None                    0.0
# 2                None                    0.0
# 3                None               127845.0
# 4                None                 9000.0
# 5                None                    0.0
# 6                None                21000.0
# 7                None                    0.0
# 8                None                    0.0
# 9                None               143200.0
# 10               None                    0.0
# 11  See Attached Spec                 5000.0
# 12       See Attached                12500.0
# 13               None                    0.0
# 14               None                    0.0
# 15               None                    0.0
# 16               None                    0.0
# 17               None                    0.0
# 18               None                    0.0
# 19               None                 2000.0
# 20               None                 1000.0
# 21               None                    0.0
# 22               None                    0.0
# 23               None               245000.0
# 24               None                    0.0
# 25               None                    0.0
# 26               None                    0.0
# 27               None                    0.0
# 28               None                    0.0
# 29               None                    0.0
# 30               None                    0.0
# 31               None                    0.0
# 32               None                    0.0
# 33               None                    0.0
# 34               None                    0.0
# 35               None              -500000.0
# 36               None                    0.0
# 37               None                    0.0
# 38               None                    0.0
# 39               None                    0.0
# 40               None                 2000.0
# 41               None                10000.0
# 42               None              1100000.0
# 43               None               225000.0
# 44               None                    0.0
# 45               None                    0.0
# 46               None                40000.0
# 47               None                    0.0
# 48               None                75000.0
# 49               None                    0.0
#
#                                            AssignedTo  AwardDate  ...  \
# 0                                                None        NaT  ...
# 1                                                None        NaT  ...
# 2                                                None        NaT  ...
# 3                                                None 2020-04-01  ...
# 4                                                None        NaT  ...
# 5                                                None        NaT  ...
# 6                                 Pat The PM - Summit        NaT  ...
# 7                                                None        NaT  ...
# 8                                                None        NaT  ...
# 9                                                None        NaT  ...
# 10                                               None        NaT  ...
# 11                                Joe Momand - Summit 2020-07-29  ...
# 12                                               None 2020-07-29  ...
# 13                                               None 2020-08-14  ...
# 14                                               None        NaT  ...
# 15                                               None 2020-08-14  ...
# 16                                               None        NaT  ...
# 17                                               None        NaT  ...
# 18                                               None        NaT  ...
# 19                                               None        NaT  ...
# 20                                               None        NaT  ...
# 21                                               None        NaT  ...
# 22                                               None        NaT  ...
# 23                                               None        NaT  ...
# 24                                               None        NaT  ...
# 25                                               None        NaT  ...
# 26                                               None        NaT  ...
# 27                                               None        NaT  ...
# 28                                               None        NaT  ...
# 29                                               None        NaT  ...
# 30                                               None        NaT  ...
# 31                                               None        NaT  ...
# 32                                               None        NaT  ...
# 33                                               None        NaT  ...
# 34                                               None        NaT  ...
# 35                                               None        NaT  ...
# 36                                               None        NaT  ...
# 37                                               None        NaT  ...
# 38                                Pat The PM - Summit        NaT  ...
# 39                                               None        NaT  ...
# 40                                               None        NaT  ...
# 41                                               None        NaT  ...
# 42                                               None        NaT  ...
# 43                                               None        NaT  ...
# 44  ACME  General Contractor - ACME General Contra...        NaT  ...
# 45                                               None        NaT  ...
# 46                                               None        NaT  ...
# 47                                               None        NaT  ...
# 48                                               None        NaT  ...
# 49                                               None        NaT  ...
#
#     CurrencyCode CurrencyRateId  CurrencyRateTypeId  CurrencyRateToDomain  \
# 0            USD            714                 617                   1.0
# 1            USD            714                 617                   1.0
# 2            USD            714                 617                   1.0
# 3            USD            714                 617                   1.0
# 4            USD            714                 617                   1.0
# 5            USD            714                 617                   1.0
# 6            USD            714                 617                   1.0
# 7            USD            714                 617                   1.0
# 8            USD            714                 617                   1.0
# 9            USD            714                 617                   1.0
# 10           USD            714                 617                   1.0
# 11           USD            714                 617                   1.0
# 12           USD            714                 617                   1.0
# 13           USD            714                 617                   1.0
# 14           USD            714                 617                   1.0
# 15           USD            714                 617                   1.0
# 16           USD            714                 617                   1.0
# 17           USD            714                 617                   1.0
# 18           USD            714                 617                   1.0
# 19           USD            714                 617                   1.0
# 20           USD            714                 617                   1.0
# 21           USD            714                 617                   1.0
# 22           USD            714                 617                   1.0
# 23           USD            714                 617                   1.0
# 24           USD            714                 617                   1.0
# 25           USD            714                 617                   1.0
# 26           USD            714                 617                   1.0
# 27           USD            714                 617                   1.0
# 28           USD            714                 617                   1.0
# 29           USD            714                 617                   1.0
# 30           USD            714                 617                   1.0
# 31           USD            714                 617                   1.0
# 32           USD            714                 617                   1.0
# 33           USD            714                 617                   1.0
# 34           USD            714                 617                   1.0
# 35           USD            714                 617                   1.0
# 36           USD            714                 617                   1.0
# 37           USD            714                 617                   1.0
# 38           USD            714                 617                   1.0
# 39           USD            714                 617                   1.0
# 40           USD            714                 617                   1.0
# 41           USD            714                 617                   1.0
# 42           USD            714                 617                   1.0
# 43           USD            714                 617                   1.0
# 44           USD            714                 617                   1.0
# 45           USD            714                 617                   1.0
# 46           USD            714                 617                   1.0
# 47           USD            714                 617                   1.0
# 48           USD            714                 617                   1.0
# 49           USD            714                 617                   1.0
#
#     CurrencyRateToDocument  CurrencyRateLastModifiedDateTime  \
# 0                      1.0           2020-06-03 15:47:37.000
# 1                      1.0           2020-06-03 15:50:54.960
# 2                      1.0           2020-06-03 16:30:52.753
# 3                      1.0           2020-06-03 21:35:50.220
# 4                      1.0           2020-07-07 17:10:49.040
# 5                      1.0           2020-07-17 13:44:40.153
# 6                      1.0           2020-07-17 13:46:55.217
# 7                      1.0           2020-07-17 13:49:19.890
# 8                      1.0           2020-07-20 13:29:37.560
# 9                      1.0           2020-07-26 21:36:18.437
# 10                     1.0           2020-07-26 22:00:46.097
# 11                     1.0           2020-07-29 16:11:01.840
# 12                     1.0           2020-07-29 16:43:23.917
# 13                     1.0           2020-08-14 21:30:11.480
# 14                     1.0           2020-08-14 21:33:25.153
# 15                     1.0           2020-08-14 21:40:14.127
# 16                     1.0           2021-01-03 21:18:22.883
# 17                     1.0           2021-02-17 18:51:04.317
# 18                     1.0           2021-02-17 18:52:02.847
# 19                     1.0           2021-03-02 15:55:49.223
# 20                     1.0           2021-03-02 15:56:36.237
# 21                     1.0           2021-03-02 16:51:10.060
# 22                     1.0           2021-03-08 18:41:37.417
# 23                     1.0           2021-03-08 18:53:59.183
# 24                     1.0           2021-03-09 21:53:11.543
# 25                     1.0           2021-03-09 21:54:01.147
# 26                     1.0           2021-03-09 21:56:08.510
# 27                     1.0           2021-03-09 21:57:48.523
# 28                     1.0           2021-03-09 21:58:48.813
# 29                     1.0           2021-03-09 22:00:13.420
# 30                     1.0           2021-03-09 22:01:13.587
# 31                     1.0           2021-03-09 22:02:09.277
# 32                     1.0           2021-03-09 22:03:31.633
# 33                     1.0           2021-03-09 22:04:18.733
# 34                     1.0           2021-03-09 22:05:36.757
# 35                     1.0           2021-03-09 22:06:26.030
# 36                     1.0           2021-03-10 14:26:52.890
# 37                     1.0           2021-03-11 16:39:16.403
# 38                     1.0           2021-03-23 14:20:09.293
# 39                     1.0           2021-03-29 21:33:40.693
# 40                     1.0           2021-03-31 15:14:57.640
# 41                     1.0           2021-03-31 15:22:01.780
# 42                     1.0           2021-04-01 18:58:43.170
# 43                     1.0           2021-04-07 17:44:39.897
# 44                     1.0           2021-04-07 17:48:44.287
# 45                     1.0           2021-04-14 14:08:42.820
# 46                     1.0           2021-04-22 16:45:01.813
# 47                     1.0           2021-04-22 16:46:58.870
# 48                     1.0           2021-04-27 19:54:21.997
# 49                     1.0           2021-05-07 15:15:27.723
#
#     LinkChangeOrderItemsToContractItems  CreatedBy_Id CostUnitEntryType  \
# 0                                  None     5005854.0        TotalValue
# 1                                  None     5005854.0        TotalValue
# 2                                  None     5005854.0        TotalValue
# 3                                  None     5005854.0        TotalValue
# 4                                  None     5005854.0        TotalValue
# 5                                  None     5005854.0        TotalValue
# 6                                  None     5005854.0        TotalValue
# 7                                  None     5005854.0        TotalValue
# 8                                  None     5373886.0        TotalValue
# 9                                  None     5007445.0         UnitPrice
# 10                                 None     5007445.0        TotalValue
# 11                                 None     5007445.0         UnitPrice
# 12                                 None     5007445.0         UnitPrice
# 13                                 None     5007445.0        TotalValue
# 14                                 None     5007445.0        TotalValue
# 15                                 None     5007445.0        TotalValue
# 16                                 None     5007445.0        TotalValue
# 17                                 None     5005854.0        TotalValue
# 18                                 None     5005854.0        TotalValue
# 19                                 None     5005854.0        TotalValue
# 20                                 None     5005854.0        TotalValue
# 21                                 None     6635512.0        TotalValue
# 22                                 None     6614238.0        TotalValue
# 23                                 None     6614238.0        TotalValue
# 24                                 None     6634945.0        TotalValue
# 25                                 None     6634945.0        TotalValue
# 26                                 None     6634945.0        TotalValue
# 27                                 None     6634945.0        TotalValue
# 28                                 None     6634945.0        TotalValue
# 29                                 None     6634945.0        TotalValue
# 30                                 None     6634945.0        TotalValue
# 31                                 None     6634945.0        TotalValue
# 32                                 None     6634945.0        TotalValue
# 33                                 None     6634945.0        TotalValue
# 34                                 None     6634945.0        TotalValue
# 35                                 None     6634945.0        TotalValue
# 36                                 None     5007445.0        TotalValue
# 37                                 None     5007445.0         UnitPrice
# 38                                 None     5007445.0         UnitPrice
# 39                                 None           NaN        TotalValue
# 40                                 None     5005854.0        TotalValue
# 41                                 None     5005854.0        TotalValue
# 42                                 None     5005854.0        TotalValue
# 43                                 None     5373874.0        TotalValue
# 44                                 None     5373874.0        TotalValue
# 45                                 None     5005854.0        TotalValue
# 46                                 None     5005854.0        TotalValue
# 47                                 None     5005854.0        TotalValue
# 48                                 None     5005854.0        TotalValue
# 49                                 None     5007445.0        TotalValue
#
#     OverbillingLimits
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
# 5                None
# 6                None
# 7                None
# 8                None
# 9                None
# 10               None
# 11               None
# 12               None
# 13               None
# 14               None
# 15               None
# 16               None
# 17               None
# 18               None
# 19               None
# 20               None
# 21               None
# 22               None
# 23               None
# 24               None
# 25               None
# 26               None
# 27               None
# 28               None
# 29               None
# 30               None
# 31               None
# 32               None
# 33               None
# 34               None
# 35               None
# 36               None
# 37               None
# 38               None
# 39               None
# 40               None
# 41               None
# 42               None
# 43               None
# 44               None
# 45               None
# 46               None
# 47               None
# 48               None
# 49               None
#
# [50 rows x 95 columns]

# %%
# Search for XML tokens, portable views, and related tables
print("🔍 Searching for XML/Portable View related tables:\n")

for keyword in ['xml', 'token', 'portable', 'view', 'template', 'report']:
    results = search_tables(keyword)
    if len(results) > 0:
        print(results['TABLE_NAME'].tolist())
    print()
# Out:
# 🔍 Searching for XML/Portable View related tables:
#
# Found 0 tables matching 'xml':
#
# Found 0 tables matching 'token':
#
# Found 0 tables matching 'portable':
#
# Found 62 tables matching 'view':
# ['centrenium_PhasegateItem_PhasegateItemReviewApprovalStep', 'centrenium_PhasegateItem_PhasegateItem_CompletedSetupReviews', 'centrenium_PhasegateItem_PhasegateItem_CompletedCompletionReviews', 'kahua_PurchaseOrderChangeOrder_PurchaseOrderChangeOrder_ReviewResults', 'centrenium_PhasegateStage_PhasegateStageSetupReviewApproval', 'centrenium_PhasegateItem_PhasegateItem_SetupReviewItems', 'centrenium_PhasegateStage_PhasegateStageSetupReviewApproval_Steps', 'kahua_Issue_Issue_ReviewResults', 'kahua_AEC_Invoice_Invoice_ReviewResults', 'centrenium_PhasegateItem_PhasegateItem_CompletionReviewItems', 'kahua_AEC_SubmittalItem_SubmittalItem_OfficialReviewer', 'kahua_AEC_SubmittalPackage_SubmittalPackage_OfficialReviewer', 'centrenium_PhasegateStage_PhasegateStageReviewApprovalStep', 'kahua_AEC_SubmittalItem_SubmittalItem_Reviewers', 'kahua_AEC_DesignReviewSets_ReviewStatusItem', 'centrenium_PhasegateStage_PhasegateStage_CompletedSetupReviews', 'kahua_AEC_SubmittalPackage_SubmittalPackage_Reviewers', 'kahua_WorkPackage_WorkPackage_SubmittalOfficialReviewer', 'kahua_AEC_DesignReviewSets_DesignReviewSet', 'centrenium_PhasegateStage_PhasegateStage_CompletedCompletionReviews', 'kahua_FundingBudget_FundingBudget_ReviewResults', 'kahua_AEC_DesignReviewSets_DesignReviewSet_ReviewFiles', 'kahua_PurchaseOrder_PurchaseOrder_ReviewResults', 'kahua_AEC_DesignReviewSets_DesignReviewSet_ReviewComments', 'ezApps_Inspection_Inspection_NotifyWhenReviewed', 'centrenium_PhasegateStage_PhasegateStage_SetupReviewItems', 'kahua_AEC_DesignReviewSets_DesignReviewSet_PreliminaryReviewers', 'kahua_AEC_DesignReviewComments_DesignReviewComment', 'kahua_AEC_DesignReviewSets_DesignReviewSet_PrimaryReviewers', 'centrenium_PhasegateStage_PhasegateStage_CompletionReviewItems', 'kahua_AEC_DesignReviewSets_DesignReviewSet_InterimReviewers', 'kahua_AEC_DesignReviewComments_DesignReviewComment_Responsible', 'kahua_AEC_DesignReviewSets_DesignReviewSet_CommentReviewers', 'kahua_AEC_DesignReviewSets_DesignReviewSet_ReviewManagers', 'kahua_ContractChangeOrder_ContractChangeOrder_ReviewResults', 'kahua_AEC_PackagedSubmittals_SubmittalReviewer', 'kahua_AEC_DesignReviewComments_DesignReviewComment_AssignedTo', 'kahua_AEC_DesignReviewComments_DesignReviewComment_Comments', 'kahua_AEC_DesignReviewComments_DesignReviewComment_ResponseHistoryItems', 'kahua_AEC_DesignReviewComments_DesignReviewComment_OutwardReferences', 'kahua_ContractInvoice_ContractInvoice_ReviewResults', 'centrenium_PhasegateStage_PhasegateReviewApprovalConfiguration', 'kahua_ContractChangeRequest_ContractChangeRequest_ReviewResults', 'kahua_AEC_Submittal_SubmittalItem_Reviewers', 'kahua_BudgetChange_BudgetChange_ReviewResults', 'centrenium_PhasegateStage_PhasegateReviewApprovalConfiguration_SetupReviewItems', 'centrenium_PhasegateStage_PhasegateReviewApprovalConfiguration_SetupApprovalItems', 'kahua_AEC_DesignReviewComments_ResponseHistoryItem', 'kahua_AEC_DesignReviewSets_DesignReviewFile', 'centrenium_PhasegateStage_PhasegateReviewApprovalConfiguration_CompletionReviewItems', 'kahua_AEC_DesignReviewSets_DesignReviewFile_ReviewerResponses', 'centrenium_PhasegateItem_PhasegateItemSetupReviewApproval', 'kahua_AEC_DesignReviewSets_DesignReviewFile_ReviewerComments', 'centrenium_PhasegateItem_PhasegateItemSetupReviewApproval_Steps', 'centrenium_PhasegateStage_PhasegateReviewApprovalConfiguration_CompletionApprovalItems', 'kahua_AEC_SubmittalItem_SubmittalItemRevision_OfficialReviewer', 'kahua_AEC_SubmittalItem_SubmittalItemRevision_Reviewers', 'centrenium_PhasegateStage_PhasegateConfigReviewApprovalItem', 'kahua_AEC_DesignReviewSets_DesignReviewFileResponse', 'kahua_Contract_Contract_ReviewResults', 'kahua_AEC_SubmittalPackage_SubmittalPackageRevision_OfficialReviewer', 'kahua_AEC_SubmittalPackage_SubmittalPackageRevision_Reviewers']
#
# Found 29 tables matching 'template':
# ['centrenium_PhasegateTemplate_PhasegateTemplate', 'centrenium_PhasegateTemplate_PhasegateTemplate_Phases', 'centrenium_PhasegateTemplate_PhasegateTemplate_Gates', 'centrenium_PhasegateTemplate_PhasegateTemplate_Stages', 'centrenium_PhasegateTemplate_PhasegateTemplate_Items', 'kahua_AEC_PunchList_Template_Template', 'centrenium_PhasegateTemplate_TemplateStage', 'centrenium_PhasegateTemplate_TemplateStage_Gates', 'centrenium_PhasegateTemplate_TemplateStage_Stages', 'centrenium_PhasegateTemplate_TemplateStage_Items', 'centrenium_PhasegateTemplate_TemplateStage_Predecessors', 'centrenium_PhasegateTemplate_TemplateStage_ItemsPredecessors', 'centrenium_PhasegateTemplate_TemplateStage_NotifyOnStart', 'centrenium_PhasegateTemplate_TemplateStage_NotifyOnCompletion', 'centrenium_PhasegateTemplate_AttributeItem', 'centrenium_PhasegateTemplate_TemplateItem', 'centrenium_PhasegateTemplate_TemplateItem_Predecessors', 'centrenium_PhasegateTemplate_TemplateItem_StagesPredecessors', 'centrenium_PhasegateTemplate_TemplateItem_AttributeItems', 'centrenium_PhasegateTemplate_TemplateItem_NotifyOnStart', 'ezApps_Checklists_ChecklistScheduler_ChecklistTemplate', 'centrenium_PhasegateTemplate_TemplateItem_NotifyOnCompletion', 'ezApps_Checklists_ChecklistScheduler_ChecklistTemplate_Location', 'ezApps_ChecklistTemplate_Template', 'ezApps_Planner_TaskTemplate_Template', 'ezApps_Checklists_ChecklistScheduler_ChecklistTemplate_Comments', 'ezApps_InspectionObservationTemplate_ObservationTemplate', 'ezApps_InspectionTemplate_Template', 'ezApps_InspectionQuestionTemplate_QuestionTemplate']
#
# Found 36 tables matching 'report':
# ['kahua_AEC_DailyReport_DailyReportFieldObservations_FieldObservationsItems', 'kahua_AEC_DailyReport_DailyReportMaterialsReceived_Company', 'kahua_AEC_DailyReport_DailyReportCompany_Location', 'kahua_AEC_DailyReport_DailyReportFieldObservations_Company', 'kahua_AEC_DailyReport_DailyReportCompany_LaborTypes', 'kahua_AEC_DailyReport_DailyReportMaterialsReceived_Location', 'kahua_AEC_DailyReport_DailyReport', 'kahua_AEC_DailyReport_DailyReport_NotesAndWorkCompleted', 'kahua_AEC_DailyReport_DailyReport_Weather', 'kahua_AEC_DailyReport_DailyReport_MaterialReceived', 'kahua_AEC_DailyReport_DailyReport_Companies', 'kahua_AEC_DailyReport_DailyReport_Equipment', 'kahua_AEC_DailyReport_DailyReport_Attachments', 'kahua_AEC_DailyReport_DailyReport_InternalLaborTracking', 'kahua_AEC_DailyReport_DailyReport_Location', 'kahua_AEC_DailyReport_DailyReport_FieldObservations', 'kahua_AEC_DailyReport_DailyReport_SignatureItem', 'kahua_AEC_DailyReport_DailyReport_Visitors', 'kahua_AEC_DailyReport_DailyReport_Incidents', 'kahua_Extract_ExtractReportRun', 'kahua_AEC_DailyReport_DailyReport_DistributionNotification', 'kahua_AEC_DailyReport_DailyReportSignature', 'kahua_AEC_DailyReport_DailyReportCompanyLaborType', 'kahua_AEC_DailyReport_DailyReportReason', 'kahua_AEC_DailyReport_DailyReportInternalLaborTracking', 'kahua_AEC_DailyReport_DailyReportNotesAndWorkCompleted', 'kahua_AEC_DailyReport_DailyReportVisitors', 'kahua_AEC_DailyReport_DailyReportNotesAndWorkCompleted_Company', 'kahua_AEC_DailyReport_DailyReportIncidents', 'kahua_AEC_DailyReport_DailyReportVisitors_Company', 'kahua_AEC_DailyReport_DailyReportIncidents_Company', 'kahua_AEC_DailyReport_DailyReportEquipment', 'kahua_AEC_DailyReport_DailyReportEquipment_Company', 'kahua_AEC_DailyReport_DailyReportCompany', 'kahua_AEC_DailyReport_DailyReportMaterialsReceived', 'kahua_AEC_DailyReport_DailyReportFieldObservations']
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
